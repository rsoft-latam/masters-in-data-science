# %% [markdown]
# <a href="https://colab.research.google.com/github/rsoft-latam/masters-in-data-science/blob/main/1-open-cv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("hola mundo")
# Out:
# hola mundo

# %%
import cv2 # OpenCV
import matplotlib.pyplot as plt # Matplotlib

image = cv2.imread("example-1.png")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# print(image.shape) # R, G, B.   # BGR
plt.imshow(image)

# %%
for item in range(6):
  print("hello" + str(item))
# Out:
# hello0
# hello1
# hello2
# hello3
# hello4
# hello5
